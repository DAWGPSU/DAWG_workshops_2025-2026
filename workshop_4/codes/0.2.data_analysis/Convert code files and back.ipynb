# %%
conda activate main2
# Out:
# (/storage/group/exd44/default/pmt5304/conda_envs/main2)
# : 1

# %%
pip install jupytext
# Out:
# ...
# (/storage/group/exd44/default/pmt5304/conda_envs/main2)
# : 1

# %%
jupytext --to notebook 1_Main_analysis_PCoA_Procrustes_CCA.Rmd
# Out:
# [jupytext] Reading 1_Main_analysis_PCoA_Procrustes_CCA.Rmd in format Rmd
# [jupytext] Writing 1_Main_analysis_PCoA_Procrustes_CCA.ipynb
# (/storage/group/exd44/default/pmt5304/conda_envs/main2)
# : 1

# %%
conda deactivate
# Out:
# (base)
# : 1

# %%
conda activate main
jupyter nbconvert "0.1. Building phylogenetic trees. Data pre-processing. R code.ipynb" --to "rmarkdown"
jupyter nbconvert "0.2. Building phylogenetic trees. Ghost-tree usage. Terminal.ipynb" --to "rmarkdown"
jupyter nbconvert "0.3. Building phylogenetic trees. Data post-processing. R code.ipynb" --to "rmarkdown"

# %%
# does not convert to RMarkdown! Use the R code below instead
conda activate main
jupyter nbconvert "0.4 Data filtration.ipynb" --to "markdown"
jupyter nbconvert "2. Bonus analysis. PCoA based on Bray-Curtis. Procrustes.ipynb" --to "markdown"
# Out:
# (main) [NbConvertApp] Converting notebook 0.4 Data filtration.ipynb to markdown
# [NbConvertApp] Writing 18599 bytes to 0.4 Data filtration.md
# (main) [NbConvertApp] Converting notebook 2. Bonus analysis. PCoA based on Bray-Curtis. Procrustes.ipynb to markdown
# [NbConvertApp] Support files will be in 2. Bonus analysis. PCoA based on Bray-Curtis. Procrustes_files/
# [NbConvertApp] Making directory 2. Bonus analysis. PCoA based on Bray-Curtis. Procrustes_files
# [NbConvertApp] Making directory 2. Bonus analysis. PCoA based on Bray-Curtis. Procrustes_files
# [NbConvertApp] Making directory 2. Bonus analysis. PCoA based on Bray-Curtis. Procrustes_files
# [NbConvertApp] Making directory 2. Bonus analysis. PCoA based on Bray-Curtis. Procrustes_files
# [NbConvertApp] Making directory 2. Bonus analysis. PCoA based on Bray-Curtis. Procrustes_files
# [NbConvertApp] Making directory 2. Bonus analysis. PCoA based on Bray-Curtis. Procrustes_files
# ...

# %%
library(rmarkdown)
# Replace "your_notebook.ipynb" with the path to your file
convert_ipynb("0.1. Building phylogenetic trees. Data pre-processing. R code.ipynb")
convert_ipynb("0.2. Building phylogenetic trees. Ghost-tree usage. Terminal.ipynb")
convert_ipynb("0.3. Building phylogenetic trees. Data post-processing. R code.ipynb")
# Out:
# Warning message:
# “Detected the following probable line magics. They do not work in R Markdown.
#
#   conda activate ghost_tree”
# Warning message:
# “Detected the following probable line magics. They do not work in R Markdown.
#
#   mkdir ../../data/data_analysis/ghost_tree”

# %%
library(rmarkdown)
# Replace "your_notebook.ipynb" with the path to your file
convert_ipynb("0.4 Data filtration.ipynb")
convert_ipynb("2. Bonus analysis. PCoA based on Bray-Curtis. Procrustes.ipynb")

# %%
convert_ipynb("1. Main_analysis_PCoA_Procrustes_CCA.ipynb")
